# %% [markdown]
# # InstaCart Project
#
# ## Ex4.8 Grouping data and Aggregating values - Task questions
#
# ### Contents
# - 1. Import libraries and data frames
# - 2. Group df by 'department_id' and aggregate mean of the 'order_number'
# - 3.  Comparing order_number averages between full dataset and 1 million rows subset
# - 4. Creating a loyalty flag for the existing customers
# - 5. Find basic statistics of product prices for each loyalty category
# - 6. Data Quality Issues - correcting prices in df
# - 7. Repeat Q5 - basic statistics of Loyal Customer Flag- 8. Derive new column for 'Low/High Spender'
# - 9. Regularity of customer orders
# - 10. Export df

# %% [markdown]
# # 01 Import libraries and data frames
# ### Q1

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create file path
path = r'//Users/amypalomino/Documents/(03.22) InstaCart Basket Analysis/02 Data'

# %%
# Import dataframe ords_prods_merged
ords_prods_merge = pd.read_pickle(
            os.path.join(path,'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32435059, 19)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda      77.0            7.0     9.0
# 1  Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                      Original Beef Jerky      23.0           19.0     4.4
# 3               Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
#
#      price_range_loc   busiest day busiest_period_of_day  max_order  \
# 0  Mid range product  Regular Busy        Average orders         10
# 1  Mid range product  Regular Busy        Average orders         10
# 2  Low range product  Regular Busy        Average orders         10
# 3  Low range product  Regular Busy        Average orders         10
# 4  Low range product  Regular Busy        Average orders         10
#
#    loyalty_flag
# 0  New customer
# 1  New customer
# 2  New customer
# 3  New customer
# 4  New customer

# %% [markdown]
# # 02 Group df by 'department_id' and aggregate mean of the 'order_number'
# ### Q 2

# %%
# Group df by 'department_id' and aggregate mean of the 'order_number'
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %% [markdown]
# # 03
# ### Q3 Comparing order_number averages between full dataset and 1 million rows subset
# - The average value per department id isn't vastly different between the 2 data frames. A couple of the department id's show a larger variance, such as 21 which had an average of 21.99 average orders within the subset but increased to 22.9 when aggregated on the full data frame.
# - Other department ids showed a smaller average when calculated on the entire data frame, such as id 20, which reduced from 17.1 on the subset to a 16.5 average on the full data set.
# - The data frame is ordered based on user_id which implies the data frame is in chronological order. From this assumption, I can then derive another assumption, that sales within department id 21 are increasing with time, but declining over time for products sold in deprtment id 20 based on the average order numbers per department.

# %% [markdown]
# # 04
# ### Q4 Creating a loyalty flag for the existing customers

# %%
ords_prods_merge['loyalty_flag'].value_counts (dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # 05
# ### Q5 Find basic statistics of product prices for each loyalty category

# %%
ords_prods_merge.groupby ('loyalty_flag').agg({'prices' : ['min', 'max', 'mean']})
# Out:
#                  prices
#                     min      max       mean
# loyalty_flag
# Loyal customer      1.0  99999.0  10.386336
# New customer        1.0  99999.0  13.294670
# Regular customer    1.0  99999.0  12.495717

# %% [markdown]
# - This is interesting and not what I expected. The new customers purchase higher average price value items than the regular or even loyal customers.
# - I need to fix the incorrect price currently stored for the 2% milk (9999.0) as this will be skewing the mean  considerably

# %% [markdown]
# # 06 - Data Quality Issues - correcting prices in df

# %%
# Setting correct price for 2 % milk which is incorrectly priced at 99999.0
ords_prods_merge.loc[ords_prods_merge['prices'] == 99999.0, 'prices'] = 0.99

# %%
# Is there another inccorect price that needs changing?
ords_prods_merge['prices'].max()
# Out:
# 14900.0

# %%
# Create subset to identify number of rows containing inccorect price of 14900.0
price = ords_prods_merge[ords_prods_merge['prices'] == 14900.0]

# %%
# How many rows contain the 14900 price?
price['prices'].value_counts (dropna = False)
# Out:
# 14900.0    4429
# Name: prices, dtype: int64

# %%
# Check product name for item priced at 14900.0
print(price)['prices','product_name']
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 1576        912404       17            12                  2
# 1638        603376       17            22                  6
# 16534      3264360      135             2                  2
# 16540       892534      135             3                  0
# 53712       229704      342             8                  1
# ...            ...      ...           ...                ...
# 32350634   3172853   205650            18                  1
# 32377867   2504315   205818             3                  5
# 32377877   1108388   205818             5                  4
# 32410707   1916142   206049             1                  2
# 32410731    379732   206049             4                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 1576                     14                     5.0       21553
# 1638                     16                     4.0       21553
# 16534                    21                    13.0       21553
# 16540                     8                    12.0       21553
# 53712                    19                    30.0       21553
# ...                     ...                     ...         ...
# 32350634                  9                     7.0       21553
# 32377867                 15                     3.0       21553
# 32377877                  5                     1.0       21553
# 32410707                 17                     NaN       21553
# 32410731                 14                     5.0       21553
#
#           add_to_cart_order  reordered _merge  \
# 1576                      5          0   both
# 1638                      3          1   both
# 16534                     6          0   both
# 16540                     3          1   both
# 53712                     9          0   both
# ...                     ...        ...    ...
# 32350634                 17          1   both
# 32377867                 13          0   both
# 32377877                  5          1   both
# 32410707                  2          0   both
# 32410731                  4          1   both
#
#                               product_name  aisle_id  department_id   prices  \
# 1576      Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 1638      Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 16534     Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 16540     Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 53712     Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# ...                                    ...       ...            ...      ...
# 32350634  Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 32377867  Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 32377877  Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 32410707  Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
# 32410731  Lowfat 2% Milkfat Cottage Cheese     108.0           16.0  14900.0
#
#              price_range_loc   busiest day busiest_period_of_day  max_order  \
# 1576      High range product  Regular Busy           Most orders         40
# 1638      High range product  Regular Busy           Most orders         40
# 16534     High range product  Regular Busy         Fewest orders          4
# 16540     High range product  Busiest Days        Average orders          4
# 53712     High range product  Busiest Days         Fewest orders         16
# ...                      ...           ...                   ...        ...
# 32350634  High range product  Busiest Days           Most orders         25
# 32377867  High range product  Regular Busy           Most orders         25
# 32377877  High range product  Slowest Days         Fewest orders         25
# 32410707  High range product  Regular Busy         Fewest orders          5
# 32410731  High range product  Busiest Days           Most orders          5
#
#               loyalty_flag
# 1576      Regular customer
# 1638      Regular customer
# 16534         New customer
# 16540         New customer
# 53712     Regular customer
# ...                    ...
# 32350634  Regular customer
# 32377867  Regular customer
# 32377877  Regular customer
# 32410707      New customer
# 32410731      New customer
#
# [4429 rows x 19 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ms/r3vjc_697bj9f824l9czk1h00000gp/T/ipykernel_9995/3196450924.py in <module>
# ----> 1 print(price)['prices','product_name']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Cottage cheese is definitely not 14900.0/unit. Correcting price to 1.49
ords_prods_merge.loc[ords_prods_merge['prices'] == 14900.0, 'prices'] = 1.49

# %%
# Look at max price in 'prices' again
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %% [markdown]
# # 07
# Repeat Q5 - basic statistics of Loyal Customer Flag

# %%
ords_prods_merge.groupby ('loyalty_flag').agg({'prices' : ['min', 'max', 'mean']})
# Out:
#                  prices
#                     min   max      mean
# loyalty_flag
# Loyal customer     0.99  25.0  7.772758
# New customer       0.99  25.0  7.800029
# Regular customer   0.99  25.0  7.797197

# %% [markdown]
# ### Average price of product across customer type
# I'm suprised again, this time by how close the average is across the 3 customer types after removing the 2 outlier prices that were skewing the results

# %%
# Want to check that the average price across the various departments looks as I would expect 
ords_prods_merge.groupby ('department_id').agg({'prices' : ['min', 'max', 'mean']})
# Out:
#               prices
#                  min   max       mean
# department_id
# 1.0             1.00  15.0   7.736553
# 2.0             1.10  15.0   6.990934
# 3.0             1.00  15.0   7.853809
# 4.0             1.00  15.0   7.981708
# 5.0             1.00  15.0   8.143701
# 6.0             1.00  15.0   7.682264
# 7.0             1.00  15.0   7.680502
# 8.0             1.00  15.0   7.889070
# 9.0             1.00  15.0   7.350283
# 10.0            1.40  14.1   8.348960
# 11.0            1.00  15.0   7.996769
# 12.0            8.00  25.0  16.294443
# 13.0            1.00  20.0   8.009443
# 14.0            1.00  14.9   8.028963
# 15.0            1.00  15.0   7.539976
# 16.0            0.99  15.0   8.328491
# 17.0            1.00  15.0   7.384058
# 18.0            1.00  15.0   7.638380
# 19.0            1.60   7.0   4.275437
# 20.0            1.00  15.0   7.778701
# 21.0            1.00  15.0   8.660716

# %% [markdown]
# # 08
# ### Q6 - Derive new column for 'Low/High Spender'

# %%
# Aggregate average price per user as 'average_price' 
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Assign 'Low Spender' flag to customers with an average_price below 10
ords_prods_merge.loc[ords_prods_merge['average_price'] <10,
                    'High/Low_Spender'] = 'Low Spender'

# %%
# Assign 'High Spender' flag to customers with an average_price equal to or above 10
ords_prods_merge.loc[ords_prods_merge['average_price'] >=10,
                    'High/Low_Spender'] = 'High Spender'

# %%
ords_prods_merge.head(60)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2539329        1             1                  2                  8
# 2    2539329        1             1                  2                  8
# 3    2539329        1             1                  2                  8
# 4    2539329        1             1                  2                  8
# 5    2398795        1             2                  3                  7
# 6    2398795        1             2                  3                  7
# 7    2398795        1             2                  3                  7
# 8    2398795        1             2                  3                  7
# 9    2398795        1             2                  3                  7
# 10   2398795        1             2                  3                  7
# 11    473747        1             3                  3                 12
# 12    473747        1             3                  3                 12
# 13    473747        1             3                  3                 12
# 14    473747        1             3                  3                 12
# 15    473747        1             3                  3                 12
# 16   2254736        1             4                  4                  7
# 17   2254736        1             4                  4                  7
# 18   2254736        1             4                  4                  7
# 19   2254736        1             4                  4                  7
# 20   2254736        1             4                  4                  7
# 21    431534        1             5                  4                 15
# 22    431534        1             5                  4                 15
# 23    431534        1             5                  4                 15
# 24    431534        1             5                  4                 15
# 25    431534        1             5                  4                 15
# 26    431534        1             5                  4                 15
# 27    431534        1             5                  4                 15
# 28    431534        1             5                  4                 15
# 29   3367565        1             6                  2                  7
# 30   3367565        1             6                  2                  7
# 31   3367565        1             6                  2                  7
# 32   3367565        1             6                  2                  7
# 33    550135        1             7                  1                  9
# 34    550135        1             7                  1                  9
# 35    550135        1             7                  1                  9
# 36    550135        1             7                  1                  9
# 37    550135        1             7                  1                  9
# 38   3108588        1             8                  1                 14
# 39   3108588        1             8                  1                 14
# 40   3108588        1             8                  1                 14
# 41   3108588        1             8                  1                 14
# 42   3108588        1             8                  1                 14
# 43   3108588        1             8                  1                 14
# 44   2295261        1             9                  1                 16
# 45   2295261        1             9                  1                 16
# 46   2295261        1             9                  1                 16
# 47   2295261        1             9                  1                 16
# 48   2295261        1             9                  1                 16
# 49   2295261        1             9                  1                 16
# 50   2550362        1            10                  4                  8
# 51   2550362        1            10                  4                  8
# 52   2550362        1            10                  4                  8
# 53   2550362        1            10                  4                  8
# 54   2550362        1            10                  4                  8
# 55   2550362        1            10                  4                  8
# 56   2550362        1            10                  4                  8
# 57   2550362        1            10                  4                  8
# 58   2550362        1            10                  4                  8
# 59   2168274        2             1                  2                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# 1                      NaN       14084                  2          0   both
# 2                      NaN       12427                  3          0   both
# 3                      NaN       26088                  4          0   both
# 4                      NaN       26405                  5          0   both
# 5                     15.0         196                  1          1   both
# 6                     15.0       10258                  2          0   both
# 7                     15.0       12427                  3          1   both
# 8                     15.0       13176                  4          0   both
# 9                     15.0       26088                  5          1   both
# 10                    15.0       13032                  6          0   both
# 11                    21.0         196                  1          1   both
# 12                    21.0       12427                  2          1   both
# 13                    21.0       10258                  3          1   both
# 14                    21.0       25133                  4          0   both
# 15                    21.0       30450                  5          0   both
# 16                    29.0         196                  1          1   both
# 17                    29.0       12427                  2          1   both
# 18                    29.0       10258                  3          1   both
# 19                    29.0       25133                  4          1   both
# 20                    29.0       26405                  5          1   both
# 21                    28.0         196                  1          1   both
# 22                    28.0       12427                  2          1   both
# 23                    28.0       10258                  3          1   both
# 24                    28.0       25133                  4          1   both
# 25                    28.0       10326                  5          0   both
# 26                    28.0       17122                  6          0   both
# 27                    28.0       41787                  7          0   both
# 28                    28.0       13176                  8          1   both
# 29                    19.0         196                  1          1   both
# 30                    19.0       12427                  2          1   both
# 31                    19.0       10258                  3          1   both
# 32                    19.0       25133                  4          1   both
# 33                    20.0         196                  1          1   both
# 34                    20.0       10258                  2          1   both
# 35                    20.0       12427                  3          1   both
# 36                    20.0       25133                  4          1   both
# 37                    20.0       13032                  5          1   both
# 38                    14.0       12427                  1          1   both
# 39                    14.0         196                  2          1   both
# 40                    14.0       10258                  3          1   both
# 41                    14.0       25133                  4          1   both
# 42                    14.0       46149                  5          0   both
# 43                    14.0       49235                  6          0   both
# 44                     0.0       49235                  1          1   both
# 45                     0.0       46149                  2          1   both
# 46                     0.0       25133                  3          1   both
# 47                     0.0         196                  4          1   both
# 48                     0.0       10258                  5          1   both
# 49                     0.0       12427                  6          1   both
# 50                    30.0         196                  1          1   both
# 51                    30.0       46149                  2          1   both
# 52                    30.0       39657                  3          0   both
# 53                    30.0       38928                  4          0   both
# 54                    30.0       25133                  5          1   both
# 55                    30.0       10258                  6          1   both
# 56                    30.0       35951                  7          0   both
# 57                    30.0       13032                  8          1   both
# 58                    30.0       12427                  9          1   both
# 59                     NaN       32792                  1          0   both
#
#     ... aisle_id  department_id  prices    price_range_loc   busiest day  \
# 0   ...     77.0            7.0     9.0  Mid range product  Regular Busy
# 1   ...     91.0           16.0    12.5  Mid range product  Regular Busy
# 2   ...     23.0           19.0     4.4  Low range product  Regular Busy
# 3   ...     23.0           19.0     4.7  Low range product  Regular Busy
# 4   ...     54.0           17.0     1.0  Low range product  Regular Busy
# 5   ...     77.0            7.0     9.0  Mid range product  Slowest Days
# 6   ...    117.0           19.0     3.0  Low range product  Slowest Days
# 7   ...     23.0           19.0     4.4  Low range product  Slowest Days
# 8   ...     24.0            4.0    10.3  Mid range product  Slowest Days
# 9   ...     23.0           19.0     4.7  Low range product  Slowest Days
# 10  ...    121.0           14.0     4.0  Low range product  Slowest Days
# 11  ...     77.0            7.0     9.0  Mid range product  Slowest Days
# 12  ...     23.0           19.0     4.4  Low range product  Slowest Days
# 13  ...    117.0           19.0     3.0  Low range product  Slowest Days
# 14  ...     21.0           16.0     8.6  Mid range product  Slowest Days
# 15  ...     88.0           13.0     3.2  Low range product  Slowest Days
# 16  ...     77.0            7.0     9.0  Mid range product  Slowest Days
# 17  ...     23.0           19.0     4.4  Low range product  Slowest Days
# 18  ...    117.0           19.0     3.0  Low range product  Slowest Days
# 19  ...     21.0           16.0     8.6  Mid range product  Slowest Days
# 20  ...     54.0           17.0     1.0  Low range product  Slowest Days
# 21  ...     77.0            7.0     9.0  Mid range product  Slowest Days
# 22  ...     23.0           19.0     4.4  Low range product  Slowest Days
# 23  ...    117.0           19.0     3.0  Low range product  Slowest Days
# 24  ...     21.0           16.0     8.6  Mid range product  Slowest Days
# 25  ...     24.0            4.0     2.7  Low range product  Slowest Days
# 26  ...     24.0            4.0    14.0  Mid range product  Slowest Days
# 27  ...     24.0            4.0     5.0  Low range product  Slowest Days
# 28  ...     24.0            4.0    10.3  Mid range product  Slowest Days
# 29  ...     77.0            7.0     9.0  Mid range product  Regular Busy
# 30  ...     23.0           19.0     4.4  Low range product  Regular Busy
# 31  ...    117.0           19.0     3.0  Low range product  Regular Busy
# 32  ...     21.0           16.0     8.6  Mid range product  Regular Busy
# 33  ...     77.0            7.0     9.0  Mid range product  Busiest Days
# 34  ...    117.0           19.0     3.0  Low range product  Busiest Days
# 35  ...     23.0           19.0     4.4  Low range product  Busiest Days
# 36  ...     21.0           16.0     8.6  Mid range product  Busiest Days
# 37  ...    121.0           14.0     4.0  Low range product  Busiest Days
# 38  ...     23.0           19.0     4.4  Low range product  Busiest Days
# 39  ...     77.0            7.0     9.0  Mid range product  Busiest Days
# 40  ...    117.0           19.0     3.0  Low range product  Busiest Days
# 41  ...     21.0           16.0     8.6  Mid range product  Busiest Days
# 42  ...     77.0            7.0    13.4  Mid range product  Busiest Days
# 43  ...     53.0           16.0     1.8  Low range product  Busiest Days
# 44  ...     53.0           16.0     1.8  Low range product  Busiest Days
# 45  ...     77.0            7.0    13.4  Mid range product  Busiest Days
# 46  ...     21.0           16.0     8.6  Mid range product  Busiest Days
# 47  ...     77.0            7.0     9.0  Mid range product  Busiest Days
# 48  ...    117.0           19.0     3.0  Low range product  Busiest Days
# 49  ...     23.0           19.0     4.4  Low range product  Busiest Days
# 50  ...     77.0            7.0     9.0  Mid range product  Slowest Days
# 51  ...     77.0            7.0    13.4  Mid range product  Slowest Days
# 52  ...     45.0           19.0     6.8  Mid range product  Slowest Days
# 53  ...    120.0           16.0    12.6  Mid range product  Slowest Days
# 54  ...     21.0           16.0     8.6  Mid range product  Slowest Days
# 55  ...    117.0           19.0     3.0  Low range product  Slowest Days
# 56  ...     91.0           16.0     1.3  Low range product  Slowest Days
# 57  ...    121.0           14.0     4.0  Low range product  Slowest Days
# 58  ...     23.0           19.0     4.4  Low range product  Slowest Days
# 59  ...     23.0           19.0     5.2  Mid range product  Regular Busy
#
#    busiest_period_of_day max_order      loyalty_flag average_price  \
# 0         Average orders        10      New customer      6.367797
# 1         Average orders        10      New customer      6.367797
# 2         Average orders        10      New customer      6.367797
# 3         Average orders        10      New customer      6.367797
# 4         Average orders        10      New customer      6.367797
# 5          Fewest orders        10      New customer      6.367797
# 6          Fewest orders        10      New customer      6.367797
# 7          Fewest orders        10      New customer      6.367797
# 8          Fewest orders        10      New customer      6.367797
# 9          Fewest orders        10      New customer      6.367797
# 10         Fewest orders        10      New customer      6.367797
# 11           Most orders        10      New customer      6.367797
# 12           Most orders        10      New customer      6.367797
# 13           Most orders        10      New customer      6.367797
# 14           Most orders        10      New customer      6.367797
# 15           Most orders        10      New customer      6.367797
# 16         Fewest orders        10      New customer      6.367797
# 17         Fewest orders        10      New customer      6.367797
# 18         Fewest orders        10      New customer      6.367797
# 19         Fewest orders        10      New customer      6.367797
# 20         Fewest orders        10      New customer      6.367797
# 21           Most orders        10      New customer      6.367797
# 22           Most orders        10      New customer      6.367797
# 23           Most orders        10      New customer      6.367797
# 24           Most orders        10      New customer      6.367797
# 25           Most orders        10      New customer      6.367797
# 26           Most orders        10      New customer      6.367797
# 27           Most orders        10      New customer      6.367797
# 28           Most orders        10      New customer      6.367797
# 29         Fewest orders        10      New customer      6.367797
# 30         Fewest orders        10      New customer      6.367797
# 31         Fewest orders        10      New customer      6.367797
# 32         Fewest orders        10      New customer      6.367797
# 33           Most orders        10      New customer      6.367797
# 34           Most orders        10      New customer      6.367797
# 35           Most orders        10      New customer      6.367797
# 36           Most orders        10      New customer      6.367797
# 37           Most orders        10      New customer      6.367797
# 38           Most orders        10      New customer      6.367797
# 39           Most orders        10      New customer      6.367797
# 40           Most orders        10      New customer      6.367797
# 41           Most orders        10      New customer      6.367797
# 42           Most orders        10      New customer      6.367797
# 43           Most orders        10      New customer      6.367797
# 44           Most orders        10      New customer      6.367797
# 45           Most orders        10      New customer      6.367797
# 46           Most orders        10      New customer      6.367797
# 47           Most orders        10      New customer      6.367797
# 48           Most orders        10      New customer      6.367797
# 49           Most orders        10      New customer      6.367797
# 50        Average orders        10      New customer      6.367797
# 51        Average orders        10      New customer      6.367797
# 52        Average orders        10      New customer      6.367797
# 53        Average orders        10      New customer      6.367797
# 54        Average orders        10      New customer      6.367797
# 55        Average orders        10      New customer      6.367797
# 56        Average orders        10      New customer      6.367797
# 57        Average orders        10      New customer      6.367797
# 58        Average orders        10      New customer      6.367797
# 59           Most orders        14  Regular customer      7.515897
#
#     High/Low_Spender
# 0        Low Spender
# 1        Low Spender
# 2        Low Spender
# 3        Low Spender
# 4        Low Spender
# 5        Low Spender
# 6        Low Spender
# 7        Low Spender
# 8        Low Spender
# 9        Low Spender
# 10       Low Spender
# 11       Low Spender
# 12       Low Spender
# 13       Low Spender
# 14       Low Spender
# 15       Low Spender
# 16       Low Spender
# 17       Low Spender
# 18       Low Spender
# 19       Low Spender
# 20       Low Spender
# 21       Low Spender
# 22       Low Spender
# 23       Low Spender
# 24       Low Spender
# 25       Low Spender
# 26       Low Spender
# 27       Low Spender
# 28       Low Spender
# 29       Low Spender
# 30       Low Spender
# 31       Low Spender
# 32       Low Spender
# 33       Low Spender
# 34       Low Spender
# 35       Low Spender
# 36       Low Spender
# 37       Low Spender
# 38       Low Spender
# 39       Low Spender
# 40       Low Spender
# 41       Low Spender
# 42       Low Spender
# 43       Low Spender
# 44       Low Spender
# 45       Low Spender
# 46       Low Spender
# 47       Low Spender
# 48       Low Spender
# 49       Low Spender
# 50       Low Spender
# 51       Low Spender
# 52       Low Spender
# 53       Low Spender
# 54       Low Spender
# 55       Low Spender
# 56       Low Spender
# 57       Low Spender
# 58       Low Spender
# 59       Low Spender
#
# [60 rows x 21 columns]

# %%
# Summary of high/low spending customer type
ords_prods_merge['High/Low_Spender'].value_counts (dropna = False)
# Out:
# Low Spender     32315213
# High Spender      119846
# Name: High/Low_Spender, dtype: int64

# %% [markdown]
# # 09.
# ### Q7 Regularity of customer orders

# %%
# Find the median of the 'days_since_prior_order' grouped by user_id
ords_prods_merge['median_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Assign 'Non-frequent' flag to customers with a median_order_frequency above 20
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] >20,
                    'Order_frequency_flag'] = 'Non-frequent customer'

# %%
# Assign 'Regular csutomer' flag to customers with a median_order_frequency between 20 and 10
ords_prods_merge.loc[(ords_prods_merge['median_order_frequency'] <=20) & 
                     (ords_prods_merge['median_order_frequency'] >10),
                    'Order_frequency_flag'] = 'Regular customer'

# %%
# Assign 'Frequent customer' flag to customers with a median_order_frequency below 10
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] <=10,
                    'Order_frequency_flag'] = 'Frequent customer'

# %%
# Summary of 3 types of order_frequency customer
ords_prods_merge['Order_frequency_flag'].value_counts (dropna = False)
# Out:
# Frequent customer        21578273
# Regular customer          7217066
# Non-frequent customer     3639720
# Name: Order_frequency_flag, dtype: int64

# %% [markdown]
# # 10. Export df

# %%
ords_prods_merge.to_pickle (os.path.join (path,'Prepared Data', 'orders_products_merged.pkl'))
